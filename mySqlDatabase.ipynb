# %%
import mysql.connector
if True:
    print("connector successful")
else:
    print("connection unsuccessful")
# Out:
# connector successful

# %%
import mysql.connector

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="2005"
)

print("connection successful\n", mydb)
# Out:
# connection successful
# ...

# %%
#creating a database named garimapy

mycursor=mydb.cursor()

mycursor.execute("CREATE DATABASE garimapy")
if mycursor.connect:
    print("Database created successfully")
else:
    print("failed to create the database")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\dell\AppData\Local\Programs\Python\Python314\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Can't create database 'garimapy'; database exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[47], line 5
#       1 #creating a database named garimapy
# ...

# %%
#to check if the database exists or not 
mycursor = mydb.cursor()
mycursor.execute("SHOW DATABASES")

for x in mycursor:
    print(x)
# Out:
# ('garimapy',)
# ('home',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('test',)
# ('xyz',)

# %%
import mysql.connector
db=mysql.connector.connect(
    user="root",
    password="",
    localhost="localhost"
)

garima=db.cursor()

garima.execute("CREATE TABLE stds(name varchar(255),address varchar(255))")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 import mysql.connector
# ----> 2 db=mysql.connector.connect(
#       3     user="root",
#       4     password="",
#       5     localhost="localhost"
#       6 )
#       8 garima=db.cursor()
#      10 garima.execute("CREATE TABLE stds(name varchar(255),address varchar(255))")
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python314\Lib\site-packages\mysql\connector\pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python314\Lib\site-packages\mysql\connector\connection_cext.py:142, in CMySQLConnection.__init__(self, **kwargs)
#     140 if kwargs:
# ...

# %%
mycursor=mydb.cursor()

mycursor.execute("SHOW TABLES")
for x in mycursor:
    print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 mycursor=mydb.cursor()
#       3 mycursor.execute("SHOW TABLES")
#       4 for x in mycursor:
#
# NameError: name 'mydb' is not defined
